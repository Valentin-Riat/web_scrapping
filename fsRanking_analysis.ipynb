# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# load data set
data_matrix = np.load("data_matrix.npy")
data = pd.DataFrame(data_matrix,
                     columns=["uni_name","points", "nb compet","first year"],
                     index=np.arange(1,280,1))

data = data.astype({'uni_name':'str', 'points':'float32', 'nb compet':'int32', 'first year':'int32'})

# %%
# get values for our team
epflrt = data[data["uni_name"] == "École Polytechnique Fédérale de Lausanne"]
our_index = epflrt.index[0]
our_nb_compet = epflrt["nb compet"].values[0]
our_first_year = epflrt["first year"].values[0]
our_points = epflrt["points"].values[0]

# %%
better_teams = data[data.index < our_index]

newest_better_team = better_teams[better_teams["first year"] == better_teams.max()["first year"]]
print("newest team : {}".format(better_teams.max()["first year"]))

mean = data.mean()
data.mean()
data.sort_values(by=["first year","points"], ascending=False)
# Out:
# newest team : 2022
# C:\Users\valen\AppData\Local\Temp\ipykernel_16448\3841732956.py:6: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean = data.mean()
# C:\Users\valen\AppData\Local\Temp\ipykernel_16448\3841732956.py:7: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
#                                           uni_name      points  nb compet  \
# 7          Pimpri Chinchwad College Of Engineering  618.739990          1
# 11                    Fachhochschule Joanneum Graz  554.330017          3
# 44                 École de Technologie Superieure  386.230011          1
# 57                               Curtin University  324.739990          1
# 62              Ulm University of Applied Sciences  312.809998          2
# ..                                             ...         ...        ...
# 116                  Technische Universität Berlin  208.960007         10
# 117  Slovak University of Technology in Bratislava  208.479996         18
# 141                     Technische Hochschule Köln  185.759995         19
# 156             Deggendorf Institute of Technology  169.399994         26
# 198      Fachhochschule für Wirtschaft und Technik  140.339996         17
#
#      first year
# 7          2022
# 11         2022
# 44         2022
# 57         2022
# 62         2022
# ..          ...
# 116        2010
# 117        2010
# 141        2010
# 156        2010
# 198        2010
#
# [279 rows x 4 columns]

# %%
age = 4
new_teams = data[data["first year"] >= 2023-age]
new_teams.head(50)
# Out:
#                                               uni_name      points  nb compet  \
# 5                   University of Michigan - Ann Arbor  641.690002          3
# 7              Pimpri Chinchwad College Of Engineering  618.739990          1
# 11                        Fachhochschule Joanneum Graz  554.330017          3
# 27             National Technical University of Athens  443.679993          5
# 30                       Brno University of Technology  439.200012          4
# 34                     Warsaw University of Technology  415.179993          1
# 37                             The University of Akron  400.559998          2
# 44                     École de Technologie Superieure  386.230011          1
# 49                               Politecnico di Milano  363.779999          6
# 57                                   Curtin University  324.739990          1
# 60                            UAS Würzburg-Schweinfurt  313.980011          9
# 62                  Ulm University of Applied Sciences  312.809998          2
# 68                           University of Southampton  297.670013          1
